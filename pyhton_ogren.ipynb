# %%
print("Hello world")
# Out:
# Hello world

# %%
a= 5
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# Burada type değişkeni değişkenin yapısını gösterir

# %%
liste=[12,12,132,3424,535433132131,123312]
liste.sort()
print(liste)

liste.reverse()

print(liste)

print(set(liste))
# Out:
# [12, 12, 132, 3424, 123312, 535433132131]
# [535433132131, 123312, 3424, 132, 12, 12]
# {3424, 535433132131, 132, 12, 123312}

# %%
liste=[12,12,132,3424,535433132131,123312]
liste+=[12]
print(liste.count(12))
print(liste)
liste.sort()
print(liste)
liste.reverse()
print(liste)
# Out:
# 3
# [12, 12, 132, 3424, 535433132131, 123312, 12]
# [12, 12, 12, 132, 3424, 123312, 535433132131]
# [535433132131, 123312, 3424, 132, 12, 12, 12]

# %%
user= {

   "mery": {


            'yas'="23",
            'adres'="sadasjdansa" ,


      },
   "ayse":{

,
"adres"="daffadfafa",
"yas"=312,


  }
}
# Out:
#   File "<ipython-input-88-3e2a6358247c>", line 6
#     'yas'="23",
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# count tekrar sayısını gösterir

# %% [markdown]
# burada sort küçükten büyüğe reverse büyükten küçüğe ama aynı tekrar eden sayılar varsa onlarıda dahil edioyr  set ise tekrar edenleri saymaz

# %%
yas1=34
yas2=input()
print("Yasinizi giriniz:")
yas2=input()
if(yas2 > yas1):
  print("Tebrikler")
else:
  print("Basaramadiniz")
# Out:
# 23
# Yasinizi giriniz:
# 45
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-cfca978d1334> in <cell line: 5>()
#       3 print("Yasinizi giriniz:")
#       4 yas2=input()
# ----> 5 if(yas2 > yas1):
#       6   print("Tebrikler")
#       7 else:
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
liste=["a","b","d","e","f"]
print(liste)
liste+=[3]
print(liste)
liste.pop(2)
print(liste)
# Out:
# ['a', 'b', 'd', 'e', 'f']
# ['a', 'b', 'd', 'e', 'f', 3]
# ['a', 'b', 'e', 'f', 3]

# %% [markdown]
# pop eleman çıkarıyo

# %%
print("Herkese merhaba ben {0} yasim {1}".format("Mert","13"))
print("Herkese merhaba ben {ad} yasim {yas}".format(ad="Mert",yas="12"))
# Out:
# Herkese merhaba ben Mert yasim 13
# Herkese merhaba ben Mert yasim 12

# %% [markdown]
# Burdaki format değeri atamaya yarar... Liste gibi düşün {0} daha doğru tabir olur

# %%
liste=12
print(liste)
# Out:
# 12

# %%
liste=[13,123,23132,41242141]
liste[:2:4]
# Out:
# [13]

# %%
str ="mert"
str ="GURHAN"

print("gurhan".lower())
"mert".upper()
# Out:
# gurhan
# 'MERT'

# %%
liste=["ALİ,AYSE,NUR"]
print(liste.sep(*))

# %%
isim = "kerteriz ile Python öğreniyorum"

# 4. indeksten 10.indekse kadar
isim[4:10]
# Out:
# 'eriz i'

# %%
liste={10,20,123,23,42,21}
len(liste)
# Out:
# 6

# %%
# Dizi elemanlarını büyüktenten küçüğe doğru sıralar
liste =  [43,35,78,13,5,86,90]
liste.sort(reverse=False)

# %%
print("Lutfen assagidaki bilgileri doldurunuz:")
adiniz=input("Adinizi giriniz:")
soy_isim=input("Soyisim giriniz:")
yas=input("Yas giriniz:")
print("\nBilgiler yukleniyor...")
print("Ogrencimiz",adiniz,soy_isim,yas,"yasindadir")
# Out:
# Lutfen assagidaki bilgileri doldurunuz:
# Adinizi giriniz:zirzop
# Soyisim giriniz:kedy
# Yas giriniz:21
#
# Bilgiler yukleniyor...
# Ogrencimiz zirzop kedy 21 yasindadir

# %%
tuttuğum_sayı = 23.5

bilbakalım = float(input("Aklımdan bir sayı tuttum. Bil bakalım kaç tuttum? "))

if bilbakalım == tuttuğum_sayı:
    print("Tebrikler! Bildiniz...")

else:
    print("Ne yazık ki tuttuğum sayı bu değildi...")
# Out:
# Aklımdan bir sayı tuttum. Bil bakalım kaç tuttum? 23.5
# Tebrikler! Bildiniz...

# %%
hava_durumu="kotu"
if(hava_durumu=="kotu"):
  print("Sicis")
# Out:
# Sicis

# %%
yorum_birakanlar = ["Ismail Aydemir", "Uygar Aydin", "Naz Yagcioglu","Ferhat Ibrik","Ulas Acil", "Bilal Kurucay","Mert Gürhan"]

for kullanici in yorum_birakanlar:
  print(kullanici)
# Out:
# Ismail Aydemir
# Uygar Aydin
# Naz Yagcioglu
# Ferhat Ibrik
# Ulas Acil
# Bilal Kurucay
# Mert Gürhan

# %%
##kullanici_sayi = 0
#for isim in yorum_birakanlar:
   # kullanici_sayi+=1
    #print(kullanici_sayi, isim)
yorum_birakanlar = ["Ismail Aydemir", "Uygar Aydin", "Naz Yagcioglu","Ferhat Ibrik","Ulas Acil", "Bilal Kurucay"]
kullanici_sayi=0
for kullanici in yorum_birakanlar:
  kullanici_sayi+=1
  print(kullanici_sayi,kullanici)
# Out:
# 1 Ismail Aydemir
# 2 Uygar Aydin
# 3 Naz Yagcioglu
# 4 Ferhat Ibrik
# 5 Ulas Acil
# 6 Bilal Kurucay

# %% [markdown]
# split boşluktan sonra ayırıyor

# %%
from pickle import APPEND
moderator = "Mert Gürhan"

kullanici_sayi = 0
moderator_sayi = 0


for isim in yorum_birakanlar:
    ad, soyad = isim.split()[0], isim.split()[1]
    if(isim == moderator):
        moderator_sayi+=1
        print('{}. Moderatörün Adi {}, Soyadi {}'.format(moderator_sayi,ad,soyad))
    else:
        kullanici_sayi+=1
        print('{}. Katilimcinin Adi {}, Soyadi {}'.format(kullanici_sayi,ad,soyad))
# Out:
# 1. Katilimcinin Adi Ismail, Soyadi Aydemir
# 2. Katilimcinin Adi Uygar, Soyadi Aydin
# 3. Katilimcinin Adi Naz, Soyadi Yagcioglu
# 4. Katilimcinin Adi Ferhat, Soyadi Ibrik
# 5. Katilimcinin Adi Ulas, Soyadi Acil
# 6. Katilimcinin Adi Bilal, Soyadi Kurucay
# 1. Moderatörün Adi Mert, Soyadi Gürhan

# %%
index=0
harfler=["a","b","c","d"]
for harf in harfler:
  index+=1
  if harf=="c":
    print("{}.harf{}.konumda ve{}. indexte".format(harf,index,index-1))
    break
# Out:
# c harfi 3 konumda ve 2. indexte!
# c.harf3.konumda ve2. indexte

# %%
ulkeler = ['TR', 'FR', 'DE']
siralama = [1,2,3]
for ulke in zip(siralama, ulkeler):
    print(ulke)
# Out:
# (1, 'TR')
# (2, 'FR')
# (3, 'DE')

# %%
#ferhat ibriğin uzmanlık alanını gösteririnz
kullanici1 = {
    'ad': 'Ferhat',
    'soyad': 'Ibrik',
    'uzmanlik': ['Front-End']
}
kullanici2 = {
    'ad': 'Gokce',
    'soyad': 'Gün',
    'uzmanlik': ['Tasarim']
}
kullanici3 = {
    'ad': 'Mesut',
    'soyad': 'Gün',
    'uzmanlik': ['Front-End']
}

kullanici1.get("uzmanlik")
# Out:
# ['Front-End']

# %%
kullanici_listesi = [kullanici1, kullanici2, kullanici3]
kullanici1 = {
    'ad': 'Ferhat',
    'soyad': 'Ibrik',
    'uzmanlik': ['Front-End']
}
kullanici2 = {
    'ad': 'Gokce',
    'soyad': 'Gün',
    'uzmanlik': ['Tasarim']
}
kullanici3 = {
    'ad': 'Mesut',
    'soyad': 'Gün',
    'uzmanlik': ['Front-End']
}

#1.soru cevabı #kullanici1.get("uzmanlik")

kullanici_listesi = [kullanici1, kullanici2, kullanici3]

# Soru 2: Front-end alanindaki uzmanlarin isimlerini döndür
for kullanici in kullanici_listesi:
    if 'Front-End' in kullanici.get('uzmanlik'):
        print(kullanici.get('ad'))
# Out:
# Ferhat
# Mesut

# %%
# Soru 3: Mesut kullanicisi Yazilim ögrendi, bilgileri güncelle!
kullanici3['uzmanlik'].append('Yazilim')
print(kullanici_listesi)
# Out:
# [{'ad': 'Ferhat', 'soyad': 'Ibrik', 'uzmanlik': ['Front-End']}, {'ad': 'Gokce', 'soyad': 'Gün', 'uzmanlik': ['Tasarim']}, {'ad': 'Mesut', 'soyad': 'Gün', 'uzmanlik': ['Front-End', 'Yazilim']}]

# %%
#Birden fazla kullanıcı hangisisyle uğraşıyosa

for kullanici in kullanici_listesi:
  if len(kullanici["uzmanlik"])>1:
    print(kullanici)
# Out:
# {'ad': 'Mesut', 'soyad': 'Gün', 'uzmanlik': ['Front-End', 'Yazilim']}

# %%
# Soru 5: zip kullanarak iki listeyi birlestir ve yasi 30'dan az olan kullanicilar kimler?
kullanici_yaslari_listesi=[22,34,32]

for kullanici,yas in zip(kullanici_listesi,kullanici_yaslari_listesi):
  if yas<30:
    print(kullanici)
# Out:
# {'ad': 'Ferhat', 'soyad': 'Ibrik', 'uzmanlik': ['Front-End']}

# %%
deger = 7
x=deger-1
while x>1:
    if deger%x==0:
        print('{} sayisi asal degil!'.format(deger))
        break
    else:
        x-=1
else:
    print('{} sayisi asaldir!'.format(deger))
# Out:
# 7 sayisi asaldir!

# %%
# Out:
# selam sayi gir:2

# %%
a=int(input("Sayi giriniz:"))
 if (a>0 && a!=0):
  print( "pozitif sayi")
else:
  print("Negatif sayi")
# Out:
#   File "<ipython-input-7-387433357605>", line 2
#     if (a>0 && a!=0):
#     ^
# IndentationError: unexpected indent

# %%
sayi1=int(input("Bir sayi giriniz:"))
if sayi1%2==0:
  print("Cift sayi girdiniz:")
else:
  print("Tek sayi girdiniz:")


#çift mi tek mi
# Out:
# Bir sayi giriniz:23
# Tek sayi girdiniz:

# %%
import random

kelimeler = ["kedi", "köpek", "kablumbağa", "yunus", "balina", "fok", "arı", "atmaca", "güvercin", "aslan"]
secilen_kelime = random.choice(kelimeler)
gecerliHarfler = "abcçdefgğhıijklmnoöpqrsştuüvwxyz"
toplamHak = 5
yapilanTahmin = ""

# Oyun görselleri
ADAM_ASMACA_GORSLLERI = [
    """
      --------
      |    |
      |
      |
      |
      |
    """,
    """
      --------
      |    |
      |    O
      |
      |
      |
    """,
    """
      --------
      |    |
      |    O
      |    |
      |
      |
    """,
    """
      --------
      |    |
      |    O
      |   /|
      |
      |
    """,
    """
      --------
      |    |
      |    O
      |   /|\
      |
      |
    """,
    """
      --------
      |    |
      |    O
      |   /|\
      |   /
      |
    """,
    """
      --------
      |    |
      |    O
      |   /|\
      |   / \
      |
    """
]

print("Adam Asmaca Oyununa Hoş Geldiniz!")
while toplamHak > 0:
    gercekKelime = ""
    for harf in secilen_kelime:
        if harf in yapilanTahmin:
            gercekKelime += harf
        else:
            gercekKelime += "_ "

    if gercekKelime == secilen_kelime:
        print(gercekKelime)
        print("Tebrikler kazandınız!")
        break

    print(ADAM_ASMACA_GORSLLERI[5 - toplamHak])
    print("Hayvan adını tahmin edin:", gercekKelime)
    print(f"Kalan hakkınız: {toplamHak}")

    tahmin = input("Bir harf tahmin edin: ").lower()

    if tahmin in gecerliHarfler:
        yapilanTahmin += tahmin
        if tahmin not in secilen_kelime:
            toplamHak -= 1
    else:
        print("Lütfen geçerli bir harf giriniz...")

else:
    print("Maalesef kaybettiniz. Doğru kelime:", secilen_kelime)
# Out:
# Adam Asmaca Oyununa Hoş Geldiniz!
#
#       --------
#       |    |
#       |
#       |
#       |
#       |
#
# Hayvan adını tahmin edin: _ _ _
# Kalan hakkınız: 5
# Bir harf tahmin edin: A
#
#       --------
#       |    |
#       |    O
#       |
#       |
#       |
#
# Hayvan adını tahmin edin: _ _ _
# Kalan hakkınız: 4
# Bir harf tahmin edin: K
#
#       --------
#       |    |
#       |    O
#       |
#       |
#       |
#
# Hayvan adını tahmin edin: _ _ k
# Kalan hakkınız: 4
# Bir harf tahmin edin: B
#
#       --------
#       |    |
#       |    O
#       |    |
#       |
#       |
#
# Hayvan adını tahmin edin: _ _ k
# Kalan hakkınız: 3
# Bir harf tahmin edin: E
#
#       --------
#       |    |
#       |    O
#       |   /|
#       |
#       |
#
# Hayvan adını tahmin edin: _ _ k
# Kalan hakkınız: 2
# Bir harf tahmin edin: U
#
#       --------
#       |    |
#       |    O
#       |   /|      |
#       |
#
# Hayvan adını tahmin edin: _ _ k
# Kalan hakkınız: 1
# ...

# %%
import random
print("Sayi tahmin oyununa hosgeldiniz:")
oynamak_istiyor_musun ="evet"
while oynamak_istiyor_musun=="evet":
  cevap=random.randint(1,100)
  tahmin=int(input("1 ile 100 arasi sayi gir:"))
  hak=1
  while tahmin!=cevap:
    if tahmin>cevap:
      print("Yanlis,daha kucuk")
    if tahmin<cevap:
      print("Yanlis,daha buuyk")
    tahmin=int(input("1 ile 100 arasi sayi gir"))
    hak+=1

  print(f"Tebrikler, kazandın! kazanan tahmin: {cevap}")
  oynamak_istiyor_musun = input("Yeni bir oyun atmak istiyor musun? 'Evet', 'Hayır' \n")
# Out:
# Sayi tahmin oyununa hosgeldiniz:

# %%
from pandas.core.frame import DataFrame
import pandas as pd

dataframe=pd.read_excel("b.xlsx")
dataframe[' Asansör']==886
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# Name:  Asansör, dtype: bool

# %%
from xlrd import sheet
from pandas.core.frame import DataFrame
import pandas as pd
dataframe=pd.read_excel("a.xlsx")
dataframe
# Out:
#                                (M) Cancer  (M) Number  \
# 0   Allcancersexcl.non-melanomaskincancer    128802.0
# 1                                    Lung     34207.0
# 2                                Prostate     19444.0
# 3                              Colorectum     11989.0
# 4                                 Bladder     10476.0
# 5                                 Stomach      8187.0
# 6                                Pancreas      4822.0
# 7                               Leukaemia      3957.0
# 8                                  Larynx      3805.0
# 9                                   Liver      3480.0
# 10                    Non-Hodgkinlymphoma      3310.0
# 11                                 Kidney      3282.0
# 12             Brain,centralnervoussystem      3196.0
# 13                                Thyroid      2648.0
# 14                                 Testis      1605.0
# 15                        Multiplemyeloma      1491.0
# ...

# %%
import matplotlib.pyplot as plt

cancer_isimler = ['Allcancersexcl.non-melanomaskincancer', 'Lung', 'Prostate', 'Colorectum', 'Bladder', 'Stomach', 'Pancreas', 'Leukaemia', 'Larynx', 'Liver', 'Non-Hodgkinlymphoma', 'Kidney', 'Brain,centralnervoussystem', 'Thyroid', 'Testis', 'Multiplemyeloma', 'Lip,oralcavity', 'Melanomaofskin', 'Hodgkinlymphoma', 'Oesophagus', 'Nasopharynx', 'Mesothelioma', 'Kaposisarcoma', 'Salivaryglands', 'Gallbladder', 'Oropharynx', 'Hypopharynx', 'Penis']
cancer_sayilari = [128802, 34207, 19444, 11989, 10476, 8187, 4822, 3957, 3805, 3480, 3310, 3282, 3196, 2648, 1605, 1491, 1407, 890, 837, 824, 813, 466, 347, 308, 249, 169, 150, 23]

plt.figure(figsize=(12, 12))
plt.pie(cancer_sayilari, labels=cancer_isimler, autopct='%1.1f%%', startangle=90)
plt.title('Kanser Türlerine Göre Dağılım(M)')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

cancer_isimler = ['Allcancersexcl.non-melanomaskincancer', 'Lung', 'Prostate', 'Colorectum', 'Bladder', 'Stomach', 'Pancreas', 'Leukaemia', 'Larynx', 'Liver', 'Non-Hodgkinlymphoma', 'Kidney', 'Brain,centralnervoussystem', 'Thyroid', 'Testis', 'Multiplemyeloma', 'Lip,oralcavity', 'Melanomaofskin', 'Hodgkinlymphoma', 'Oesophagus', 'Nasopharynx', 'Mesothelioma', 'Kaposisarcoma', 'Salivaryglands', 'Gallbladder', 'Oropharynx', 'Hypopharynx', 'Penis']
cancer_sayilari = [128802, 34207, 19444, 11989, 10476, 8187, 4822, 3957, 3805, 3480, 3310, 3282, 3196, 2648, 1605, 1491, 1407, 890, 837, 824, 813, 466, 347, 308, 249, 169, 150, 23]
renkler = plt.cm.tab20c(np.arange(len(cancer_isimler)))
plt.figure(figsize=(15, 8))
plt.bar(cancer_isimler, cancer_sayilari, color=renkler)
plt.xlabel('Kanser Türleri')
plt.ylabel('Vaka Sayısı')
plt.title('Kanser Türlerine Göre Vaka Sayısı (M)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt


cancer_isimler = ['Allcancersexcl.non-melanomaskincancer', 'Lung', 'Prostate', 'Colorectum', 'Bladder', 'Stomach', 'Pancreas', 'Leukaemia', 'Larynx', 'Liver', 'Non-Hodgkinlymphoma', 'Kidney', 'Brain,centralnervoussystem', 'Thyroid', 'Testis', 'Multiplemyeloma', 'Lip,oralcavity', 'Melanomaofskin', 'Hodgkinlymphoma', 'Oesophagus', 'Nasopharynx', 'Mesothelioma', 'Kaposisarcoma', 'Salivaryglands', 'Gallbladder', 'Oropharynx', 'Hypopharynx', 'Penis']
cancer_sayilari = [128802, 34207, 19444, 11989, 10476, 8187, 4822, 3957, 3805, 3480, 3310, 3282, 3196, 2648, 1605, 1491, 1407, 890, 837, 824, 813, 466, 347, 308, 249, 169, 150, 23]

plt.figure(figsize=(10, 6))
plt.hist(cancer_sayilari, bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Vaka Sayısı')
plt.ylabel('Frekans')
plt.title('Kanser Vaka Sayısı(M) Histogramı')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

kanser_isimler = ['Allcancersexcl.non-melanomaskincancer', 'Breast', 'Thyroid', 'Colorectum', 'Lung', 'Corpusuteri', 'Stomach', 'Ovary', 'Pancreas', 'Leukaemia', 'Non-Hodgkinlymphoma', 'Brain,centralnervoussystem', 'Cervixuteri', 'Liver', 'Kidney', 'Bladder', 'Multiplemyeloma', 'Melanomaofskin', 'Lip,oralcavity', 'Hodgkinlymphoma', 'Oesophagus', 'Gallbladder', 'Mesothelioma', 'Larynx', 'Vulva', 'Nasopharynx', 'Salivaryglands', 'Kaposisarcoma', 'Hypopharynx', 'Vagina', 'Oropharynx']
vaka_sayilari = [98508, 24175, 11034, 9202, 7057, 5918, 4888, 4059, 3570, 3066, 2927, 2906, 2532, 2169, 1843, 1772, 1189, 866, 696, 683, 581, 518, 430, 303, 286, 276, 244, 178, 117, 111, 50]

plt.figure(figsize=(10, 10))
plt.pie(vaka_sayilari, labels=kanser_isimler, autopct='%1.1f%%', startangle=90)
plt.title('Kanser Türlerine Göre Dağılım(F)')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
kanser_isimler = ['Allcancersexcl.non-melanomaskincancer', 'Breast', 'Thyroid', 'Colorectum', 'Lung', 'Corpusuteri', 'Stomach', 'Ovary', 'Pancreas', 'Leukaemia', 'Non-Hodgkinlymphoma', 'Brain,centralnervoussystem', 'Cervixuteri', 'Liver', 'Kidney', 'Bladder', 'Multiplemyeloma', 'Melanomaofskin', 'Lip,oralcavity', 'Hodgkinlymphoma', 'Oesophagus', 'Gallbladder', 'Mesothelioma', 'Larynx', 'Vulva', 'Nasopharynx', 'Salivaryglands', 'Kaposisarcoma', 'Hypopharynx', 'Vagina', 'Oropharynx']
vaka_sayilari = [98508, 24175, 11034, 9202, 7057, 5918, 4888, 4059, 3570, 3066, 2927, 2906, 2532, 2169, 1843, 1772, 1189, 866, 696, 683, 581, 518, 430, 303, 286, 276, 244, 178, 117, 111, 50]
renkler = plt.cm.tab20c(np.arange(len(kanser_isimler)))
plt.figure(figsize=(15, 8))
plt.bar(kanser_isimler, vaka_sayilari, color=renkler)
plt.xlabel('Kanser Türleri')
plt.ylabel('Vaka Sayısı')
plt.title('Kanser Türlerine Göre Vaka Sayısı(F)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

vaka_sayilari = [98508, 24175, 11034, 9202, 7057, 5918, 4888, 4059, 3570, 3066, 2927, 2906, 2532, 2169, 1843, 1772, 1189, 866, 696, 683, 581, 518, 430, 303, 286, 276, 244, 178, 117, 111, 50]
plt.figure(figsize=(10, 6))
plt.hist(vaka_sayilari, bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Vaka Sayısı')
plt.ylabel('Frekans')
plt.title('Kanser Vaka Sayısı Histogramı(F)')
plt.show()

# %% [markdown]
# # Yeni Bölüm

# %%
import matplotlib.pyplot as plt

kanser_turleri = ['Allcancersexcl.non-melanomaskincancer', 'Breast', 'Thyroid', 'Colorectum', 'Lung', 'Corpusuteri', 'Stomach', 'Ovary', 'Pancreas', 'Leukaemia', 'Non-Hodgkinlymphoma', 'Brain,centralnervoussystem', 'Cervixuteri', 'Liver', 'Kidney', 'Bladder', 'Multiplemyeloma', 'Melanomaofskin', 'Lip,oralcavity', 'Hodgkinlymphoma', 'Oesophagus', 'Gallbladder', 'Mesothelioma', 'Larynx', 'Vulva', 'Nasopharynx', 'Salivaryglands', 'Kaposisarcoma', 'Hypopharynx', 'Vagina', 'Oropharynx']
vaka_sayilari = [98508, 24175, 11034, 9202, 7057, 5918, 4888, 4059, 3570, 3066, 2927, 2906, 2532, 2169, 1843, 1772, 1189, 866, 696, 683, 581, 518, 430, 303, 286, 276, 244, 178, 117, 111, 50]

plt.figure(figsize=(12, 6))
plt.plot(kanser_turleri, vaka_sayilari, marker='o', color='b', label='Vaka Sayısı')
plt.xlabel('Kanser Türleri')
plt.ylabel('Vaka Sayısı')
plt.title('Kanser Türlerine Göre Vaka Sayısı(F)')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt


kanser_turleri = ['Allcancersexcl.non-melanomaskincancer', 'Lung', 'Prostate', 'Colorectum', 'Bladder', 'Stomach', 'Pancreas', 'Leukaemia', 'Larynx', 'Liver', 'Non-Hodgkinlymphoma', 'Kidney', 'Brain,centralnervoussystem', 'Thyroid', 'Testis', 'Multiplemyeloma', 'Lip,oralcavity', 'Melanomaofskin', 'Hodgkinlymphoma', 'Oesophagus', 'Nasopharynx', 'Mesothelioma', 'Kaposisarcoma', 'Salivaryglands', 'Gallbladder', 'Oropharynx', 'Hypopharynx', 'Penis']
vaka_sayilari = [128802, 34207, 19444, 11989, 10476, 8187, 4822, 3957, 3805, 3480, 3310, 3282, 3196, 2648, 1605, 1491, 1407, 890, 837, 824, 813, 466, 347, 308, 249, 169, 150, 23]

vaka_sayilari = [0 if v == 'Notavailable' or v == '-' else int(v) for v in vaka_sayilari]

plt.figure(figsize=(12, 6))
plt.plot(kanser_turleri, vaka_sayilari, marker='o', color='b', label='Vaka Sayısı')
plt.xlabel('Kanser Türleri')
plt.ylabel('Vaka Sayısı')
plt.title('Kanser Türlerine Göre Vaka Sayısı(M)')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()

# %%
print("VÜCUT KİTLE ENDEKSİ HESAPLAMA PROGRAMI 💪")
boy = float(input("Boy (m):"))
kilo = int(input("Kilo (kg):"))

endeks  = kilo/(boy*boy)

if endeks <=18:
    print("\n zayıf VKİ:{}".format(endeks))
elif endeks > 18 and endeks <=25 :
    print("\n kilolu VKİ:{}".format(endeks))
elif endeks > 25 and endeks <=30:
    print("\n obez VKİ:{}".format(endeks))
elif endeks > 30:
    print("\n ciddi obez VKİ:{}".format(endeks))
# Out:
# VÜCUT KİTLE ENDEKSİ HESAPLAMA PROGRAMI 💪
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1ac0357c3337> in <cell line: 2>()
#       1 print("VÜCUT KİTLE ENDEKSİ HESAPLAMA PROGRAMI 💪")
# ----> 2 boy = float(input("Boy (m):"))
#       3 kilo = int(input("Kilo (kg):"))
#       4
#       5 endeks  = kilo/(boy*boy)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
def dikdortgenAlan(genislik, yukseklik):
    alan = float(genislik) * float(yukseklik)
    print ("Alan :",alan)
    return alan

gen = input("Genişlik :")

yuk = input("Yükseklik : ")

dikdortgenAlan(gen, yuk)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3d36a0316756> in <cell line: 6>()
#       4     return alan
#       5
# ----> 6 gen = input("Genişlik :")
#       7
#       8 yuk = input("Yükseklik : ")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
# Out:
# Mounted at /content/drive
